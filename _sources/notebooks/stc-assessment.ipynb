# %% [markdown]
# # Exercise for the GIS Market Access Specialist Role
# The work in this notebook is being done as part of the assessment for the [GIS Market Specialist](https://worldbank.github.io/GOST/content/WB_STCs.html) position. The goal of the exercise is to check and verify the candidate skills in the followign=n areas:
# 1. Use of common Python packages to deal with geospatial data
# 2. Conduct basic data and geospatial data manipulation
# 3. Conduct basic data analysis

# %% [markdown]
# ## Datasets for the analysis
# The following datasets will be used in the exercise. All the data is the exercise's data folder.
# 1. [Financial services points data](https://drive.google.com/open?id=1bxSeXe4-cFV094MX_yPb6ujePzSqfgxV&usp=drive_fs)
# 2. [2020 gridded population](https://drive.google.com/open?id=1bxSeXe4-cFV094MX_yPb6ujePzSqfgxV&usp=drive_fs)
# 3. [Financial assistance beneficiary/target communities](https://drive.google.com/open?id=1bxSeXe4-cFV094MX_yPb6ujePzSqfgxV&usp=drive_fs)
# 4. [2019 Motorized friction surface](https://drive.google.com/open?id=1bxSeXe4-cFV094MX_yPb6ujePzSqfgxV&usp=drive_fs)

# %%
## Activity-1
